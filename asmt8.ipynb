# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import decomposition
from sklearn import datasets

# %%
import pandas as pd

# %%
iris = pd.read_csv('https://raw.githubusercontent.com/singhalsak/assignment/main/iris_csv.csv')

# %%
pca = decomposition.PCA(n_components= 3)

# %%
principal_components = pca.fit_transform(x)

# %%
df_pca = pd.DataFrame(data = principal_components, columns= ['Principal comp 1', 'Principal comp 2', 'Principal comp 3'])

# %%
df_pca = df_pca.join(iris['class'])

# %%
df_pca
# Out:
#      Principal comp 1  Principal comp 2  Principal comp 3           class
# 0           -2.684207          0.326607         -0.021512     Iris-setosa
# 1           -2.715391         -0.169557         -0.203521     Iris-setosa
# 2           -2.889820         -0.137346          0.024709     Iris-setosa
# 3           -2.746437         -0.311124          0.037672     Iris-setosa
# 4           -2.728593          0.333925          0.096230     Iris-setosa
# ..                ...               ...               ...             ...
# 145          1.944017          0.187415          0.179303  Iris-virginica
# 146          1.525664         -0.375021         -0.120636  Iris-virginica
# 147          1.764046          0.078519          0.130784  Iris-virginica
# 148          1.901629          0.115877          0.722874  Iris-virginica
# 149          1.389666         -0.282887          0.362318  Iris-virginica
#
# [150 rows x 4 columns]

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111,projection = '3d')
colors = ['r', 'g', 'b']
targets = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']
for color, target in zip(colors, targets):
    indicesToKeep = df_pca['class'] == target
    ax.scatter(df_pca.loc[indicesToKeep, 'Principal comp 1'], 
               df_pca.loc[indicesToKeep, 'Principal comp 2'], 
               df_pca.loc[indicesToKeep,'Principal comp 3'], 
               c = color)
ax.set_xlabel('Principal Component 1')
ax.set_ylabel('Principal Component 2')
ax.set_zlabel('Principal Component 3')
ax.set_title('3-D transformation')
ax.legend(targets)
plt.show()
